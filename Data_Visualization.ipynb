# %% [markdown]
# <a href="https://colab.research.google.com/github/mwahajkhan/Python-For-Data-Engineering/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt

data = {'Date': ['2023-08-01', '2023-08-02', '2023-08-03'],
        'Price': [100, 105, 110]}

df = pd.DataFrame(data)

df['Data'] = pd.to_datetime(df['Date'])

df.plot(x = 'Date', y = 'Price', kind = 'line')
plt.xlabel('Date')
plt.ylabel('Price')

plt.show()

# %%
data = {'Product': ['A', 'B', 'C'],
        'Sales': [500, 750, 300]}
df = pd.DataFrame(data)

df.plot(x='Product', y = 'Sales', kind = 'bar')
plt.show()

# %%
data = {'Hours_Studied': [2, 4, 5, 7, 8, 10],
        'Exam_Score': [60, 70, 75, 85, 90, 95]}

df = pd.DataFrame(data)

df.plot(x = 'Hours_Studied', y = 'Exam_Score', kind = 'scatter')
plt.show()

# %%
data = {'Topping': ['Pepperoni', 'Mushroom', 'Olive', 'Sausage'],
        'Count': [25, 15, 10, 20]}

df = pd.DataFrame(data)

df.plot(x = 'Topping', y = 'Count', kind = 'pie')
plt.show()
